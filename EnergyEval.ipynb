# %%
# %matplotlib notebook
import matplotlib
import pandas as pd

# %%
df = pd.read_csv("2019-01-25_batcave_energy.csv", names=["s","shunt_mV","bus_V","current_mA","power_mW"])
df = df.set_index("s")
df = df.iloc[40:]

# %%
df.head(30)
# Out:
#        shunt_mV  bus_V  current_mA  power_mW
# s
# 3.978      2.65  4.184   26.200001     108.0
# 4.078      2.55  4.184   25.299999     104.0
# 4.177      2.58  4.184   25.299999     104.0
# 4.276      2.57  4.184   25.200001     102.0
# 4.375      4.55  4.148   45.099998     186.0
# 4.474      4.74  4.148   47.099998     194.0
# 4.573      4.79  4.144   47.000000     194.0
# 4.672      4.79  4.144   47.200001     196.0
# 4.771      4.77  4.144   47.799999     196.0
# 4.870      4.76  4.148   47.599998     196.0
# 4.969      6.92  4.104   69.699997     286.0
# 5.068     10.66  4.100   71.199997     292.0
# 5.167      6.09  4.124   60.900002     252.0
# 5.266      0.23  4.224    2.100000      10.0
# 5.365      0.32  4.224    2.500000      10.0
# 5.464      0.28  4.224    3.400000      14.0
# 5.563      0.24  4.224    2.700000      10.0
# 5.662      0.21  4.224    2.400000      10.0
# 5.761      0.10  4.228    1.200000       4.0
# 5.860      0.10  4.228    0.700000       4.0
# ...

# %%
df.describe()
# Out:
#            shunt_mV         bus_V    current_mA      power_mW
# count  2.174920e+06  2.174920e+06  2.174920e+06  2.174920e+06
# mean   1.795176e-01  4.170158e+00  1.793891e+00  7.627134e+00
# std    5.767216e-01  2.793915e-02  5.765419e+00  2.350034e+01
# min    3.000000e-02  3.956000e+00  3.000000e-01  0.000000e+00
# 25%    1.000000e-01  4.148000e+00  1.000000e+00  4.000000e+00
# 50%    1.100000e-01  4.168000e+00  1.100000e+00  4.000000e+00
# 75%    1.300000e-01  4.192000e+00  1.300000e+00  6.000000e+00
# max    1.066000e+01  4.232000e+00  1.021000e+02  4.160000e+02

# %%
df.iloc[100000:300000].loc[df.current_mA < 3].describe()
# Out:
#             shunt_mV          bus_V     current_mA       power_mW
# count  196782.000000  196782.000000  196782.000000  196782.000000
# mean        0.113449       4.211578       1.129091       4.914037
# std         0.058865       0.004166       0.232971       1.168284
# min         0.030000       4.036000       0.300000       4.000000
# 25%         0.100000       4.208000       1.000000       4.000000
# 50%         0.110000       4.212000       1.100000       4.000000
# 75%         0.130000       4.216000       1.300000       6.000000
# max        10.140000       4.224000       2.900000      98.000000

# %%
df.iloc[:2000].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.rolling(10000).mean().plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
